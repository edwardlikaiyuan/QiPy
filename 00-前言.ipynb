# %% [markdown]
# <img src='pics/Head.png'>
#
# <font size=14>前言</font>

# %% [markdown]
# # Python 很强大
#
# <img src="pics/库层.png" width=88%>
#
# 强大/流行 =  跨平台/胶水  +   *简洁/灵活*  +  **开源/丰富**
#
# ![image.png](attachment:ec61cd3c-481c-4a36-a0cf-b36c49b7eb21.png)
#
# ---

# %% [markdown]
# <img src='pics/WorkFlow_from_data_to_Decision.png' width=80%>
#
# 盲目分析？ → **变量可见 + 数据可视**
#
# <img src='pics/Visualization Landscape.png' width=40%>  <img src='pics/Visualization Landscape-Part.png' width=40%><img src='pics/头大.jpg' width=15%>
#
# <img src='pics/Choosing_a_python_Visualization_tool.png' width=50%>
#
# ```python
#     ax.plot()    .vs.   df.plot()    #matplotlib原生、高度可定制
#     plt.plt()    .vs.   da.plot()    #pandas、xarray等自带的也是matplotlib-based的，就是图个方便；但语法有差异
# ```

# %% [markdown]
# # 学习思路

# %% [markdown]
# - 编制 → 编辑 → 编译
#       动手就完了
# - 以气象应用为目标，需要啥学习啥；以项目建设为导向，积跬步致千里
#       人话就是：赶紧用，别等着学“全”了再用
# - 官方文档很重要，即使他是英文的；百度谷姐好搜索，Github/Gitee好托管

# %% [markdown]
# **正确对待异常、错误提示：**
# - 稍复杂一点的程序，没有“一条过”
# - 错误提示本体错误与引用错误最关键，一般也就是第一条和最后一条，再不行再往中间找
# - 搜索也要技巧（①度娘、气象家园、知乎、CSDN…… ②官方doc、example、gallery……   ③谷姐、Github、Stack Overflow……  ）
#
# ```shell
# ……warning ……  (will be) desperated……     #####这个参数、方法、属性、类要被废弃
# syntax error                            #####语法错误（中文标点符号、不适当的缩进、空格……）
# invalid character in identifier          #####语法错误（中文字符、标点、符号）
# local variable 'x' referenced before assignment    #####局部变量未声明，先使用
# TypeError: 'NoneType' object is not callable       #####变量类型不匹配
# IndentationError: unexpected indent                #####缩进问题，tab？
# NameError: name 'spam' is not defined              #####没声明
# ……not callable……                                   #####不能调用
# ……'utf-8'…can't…decode…at……0X123456 byte…            #####编码不一致
# ……except 2 position arguement，but 3 was given…………    #####参数传递数量|位置错误
# ……
# ```

# %% [markdown]
# # 学习资源

# %% [markdown]
# ## 学习资料料料料料料料料料料料料料料.zip 2.23GB
#
# ## 气Py
# [![image.png](attachment:d4a93263-d03e-4de3-a5c4-98976990e9d3.png)](https://www.youku.com/profile/index/?spm=a2hbt.13141534.1_1.1&uid=UMjM1MDUzMTQ0)
#
# ## Metpy Mondays
# [![image.png](attachment:18014edb-ce57-457d-9efc-0e4c6bad8bdb.png)](https://space.bilibili.com/676991774/channel/index)
#
# ---

# %% [markdown]
# # 课程概览

# %% [markdown]
# - 桌面操作系统 OS：  Windows - Linux - Macos/Bigsur
# - 集成开发环境IDE：  Spyder  - **Jupyter Notebook/Lab**  -  Pycharm  - vscode……
# - 数据结构是一切的基石：  天擎    气象数据网    FTP    公网……

# %% [markdown]
# ## 简单说说气象数据

# %% [markdown]
# ### 气象大数据
# <img src='data/气象大数据0.png' width=40%> <img src='data/气象大数据1.png' width=40%>
#
# <img src='data/气象大数据2.png' width=40%> <img src='data/气象大数据3.png' width=40%>

# %% [markdown]
# ### 数据种类与格式
# <img src='data/气象数据种类.png' width=60%>
#
# 格式：重要，也不重要
#   - BUFR：地面、高空、辐射……
#   - netCDF
#   - GRIB1/2
#   - AWX|HDF
#   - NEXRAD Level2|3、天气雷达新标准格式
#   - MICAPS格式
#   - txt、csv、xml、json……

# %% [markdown]
# ### 大势所趋的同质化的数据获取方式
#
# **request-response，请求-响应**（*数据库查询*）
#     - 带有参数=值的HTTP请求
#
# <img src='pics/HTTPRequest.PNG' width=40% align='left'><img src='pics/CMADAASRequest.PNG' width=40% align='right'>
# <img src='pics/GDSRequest.PNG' width=40% align='left'>
# 👈 CIMISS方式
# </br></br></br></br></br>
# CMADAAS方式 👉
# </br></br></br></br></br>
# 👈 MDFS-GDS方式

# %% [markdown]
# ## 学习/开发环境

# %% [markdown]
# ### 我安装Anaconda3的经验
# #### 添加conda-forge安装源 + 设置通道优先级
# ```shell
# >>> conda config --add channels conda-forge
# >>> conda config --add channels https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free/  #详见官网https://mirrors.tuna.tsinghua.edu.cn/help/anaconda/，比这个复杂一点点
# >>> conda config --set channel_priority flexible
# ```
#     默认的是pypi，我喜欢conda-forge，我不太想用清华源……
#     不论是哪个，要尽量统一
#
# #### 全面升级conda 及所有库包
# ```shell
# >>> conda update -n base conda
# >>> conda update –-all
# ```
#     ☀ 家中笔记本+宽带测试10mins左右
#     ☀ 单位工作站+WiFi测试20mins左右
#     ☀ 曾经培训准备全机房，机均30mins
#     ☀ 但也会有些问题，太新了也不好😔
# -----
# **以上两步之后，我还没出现过“Solving Environment:Fail”**或者很长时间
# *****

# %% [markdown]
# #### 搭建气象数据处理与可视化环境（可逐步推进）
# *虚拟环境 conda create -n env_name python=3.8*
#
# conda/pip 在线安装，离线安装（Github源码、[这里的](https://www.lfd.uci.edu/~gohlke/pythonlibs/)whl）
#
# ```shell
# >>> conda  install  netCDF4 cartopy  metpy
# >>> conda  install  -c  conda-forge  eccodes
# >>> conda  install  cfgrib
# >>> python -m cfgrib selfcheck
# ```
#     还需要在windows的系统环境变量中添加
#         ECCODES_SAMPLES_PATH = D:\Anaconda3\Library\share\eccodes\samples
#         ECCODES_DEFINITION_PATH = D:\Anaconda3\Library\share\eccodes\definitions
# ![image.png](attachment:69066044-7b6f-4653-807b-978818c64515.png)
#
# ```shell
# >>> conda  install  -c conda-forge arm_pyart  #标准雷达处理包
# >>> pip  install  pycwr     #需求PyQt5和Pyqtwebengine的版本会影响Spyder
# >>> pip  install  cinrad    #cinrad-1.6.3-cp38-cp38-win_amd64.whl
# >>> conda  install  -c conda-forge satpy  #卫星库包
# >>> conda  install  windrose      #风玫瑰图
# >>> conda  install  -c conda-forge eofs   #经验正交分解
# >>> conda  install  pycwt     #连续小波变换工具
# >>> conda  install  pymannkendall  #MK检验工具
# >>> pip  install  protobuf      #GDS访问数据需要
# >>> conda  install  httplib2   #GDS访问数据需要
# >>> conda  install  keras      #开源人工神经网络库，Tensorflow、Microsoft-CNTK和Theano的“集合”
# >>> conda  install  statsmodels#统计工具
# >>> conda  install  siphon     #用于在线获取怀俄明大学的网络探空数据
# >>> conda  install  geopandas  #地理信息处理工具
# >>> conda  install  plotly_express
# >>> conda install -c conda-forge ipywidgets
# >>> conda install h5py
# >>> conda install dask         #提高内存效率
# >>> conda install pyorbital
# >>> conda install pyspectral
# >>> conda install imageio      #读写图像
# ```
# ---
#
# 清除不关键的库包安装包/文件
#
# conda clean -a
#
# conda clean -y --all

# %% [markdown]
# ![image.png](attachment:11da6089-26c0-4b51-a4fe-9493061906e8.png)

# %% [markdown]
# ### Jupyter NoteBook/Lab的基本使用
# #### Jupyter全局设置
# 1. 工作路径
#
# ![image.png](attachment:6cb05430-a967-489a-8d1b-373dd3941190.png)
#
# 2. 开始菜单快捷方式
#   - 复制一个jupyter Notebook的快捷方式，右键属性，都改成jupyter-lab
#
# 3. 中文语言包for lab
#   - conda install -c conda-forge jupyterlab-language-pack-zh-CN #中文包
#   - 有了中文包，好像字号不能调整……
#
# 4. 字体字号…
#   #####jupyter lab字体
# ```shell
# settings => advanced settings editor => notebook
# {
#     "codeCellConfig": {
#         "fontSize": 36
#     },
#     "markdownCellConfig": {
#         "fontSize": 26
#     }
# }
# ```

# %% [markdown]
# #### Jupyter快捷键
# <div>命令模式(press <kbd>Esc</kbd> to enable)<div class="container-fluid"><div class="col-md-6"><div class="quickhelp"><span class="shortcut_key"><kbd>F</kbd></span><span class="shortcut_descr"> : 查找与替换</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Shift-F</kbd></span><span class="shortcut_descr"> : 打开命令面板</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Shift-P</kbd></span><span class="shortcut_descr"> : 打开命令面板</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Enter</kbd></span><span class="shortcut_descr"> : 进入编辑模式</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>P</kbd></span><span class="shortcut_descr"> : 打开命令面板</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Enter</kbd></span><span class="shortcut_descr"> : 运行单元格，选中下面的</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Enter</kbd></span><span class="shortcut_descr"> : 运行选中的单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Alt-Enter</kbd></span><span class="shortcut_descr"> : 运行单元格并下发插入</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Y</kbd></span><span class="shortcut_descr"> : 将单元格转为代码</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>M</kbd></span><span class="shortcut_descr"> : 将单元格转为markdown</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>R</kbd></span><span class="shortcut_descr"> : 单元格转为raw</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>1</kbd></span><span class="shortcut_descr"> : 1级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>2</kbd></span><span class="shortcut_descr"> : 2级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>3</kbd></span><span class="shortcut_descr"> : 3级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>4</kbd></span><span class="shortcut_descr"> : 4级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>5</kbd></span><span class="shortcut_descr"> : 5级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>6</kbd></span><span class="shortcut_descr"> : 6级标题</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>K</kbd></span><span class="shortcut_descr"> : 选中下面的单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Up</kbd></span><span class="shortcut_descr"> : 选中上面的单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Down</kbd></span><span class="shortcut_descr"> : 选中下面的单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>J</kbd></span><span class="shortcut_descr"> : 选择下方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-K</kbd></span><span class="shortcut_descr"> : 扩展选择上方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Up</kbd></span><span class="shortcut_descr"> : 扩展选择上方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Down</kbd></span><span class="shortcut_descr"> : 扩展选取下方单元格</span></div></div><div class="col-md-6"><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-J</kbd></span><span class="shortcut_descr"> : 扩展选取下方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-A</kbd></span><span class="shortcut_descr"> : 选择所有单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>A</kbd></span><span class="shortcut_descr"> : 上方插入单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>B</kbd></span><span class="shortcut_descr"> : 下发插入单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>X</kbd></span><span class="shortcut_descr"> : 剪切所选单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>C</kbd></span><span class="shortcut_descr"> : 复制所选单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-V</kbd></span><span class="shortcut_descr"> : 在上方粘贴单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>V</kbd></span><span class="shortcut_descr"> : 在下方粘贴单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Z</kbd></span><span class="shortcut_descr"> : 撤销</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>D</kbd>,<kbd>D</kbd></span><span class="shortcut_descr"> : 删除所选单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-M</kbd></span><span class="shortcut_descr"> : 合并所选行</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-S</kbd></span><span class="shortcut_descr"> : 保存并设置检查点</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>S</kbd></span><span class="shortcut_descr"> : 保存并设置检查点</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>L</kbd></span><span class="shortcut_descr"> : 折叠行号</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>O</kbd></span><span class="shortcut_descr"> : 切换所选单元格的输出</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-O</kbd></span><span class="shortcut_descr"> : 切换所选单元格的输出滚动</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>H</kbd></span><span class="shortcut_descr"> : 显示键盘快捷键帮助</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>I</kbd>,<kbd>I</kbd></span><span class="shortcut_descr"> : 打断Kernel</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>0</kbd>,<kbd>0</kbd></span><span class="shortcut_descr"> : 重启Kernel (with dialog)</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Esc</kbd></span><span class="shortcut_descr"> : 关闭分页</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Q</kbd></span><span class="shortcut_descr"> : 关闭分页</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-L</kbd></span><span class="shortcut_descr"> : 折叠行号</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Space</kbd></span><span class="shortcut_descr"> : 上翻页</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Space</kbd></span><span class="shortcut_descr"> : 下翻页</span></div></div></div></div>
# <br/>
#
# <div>编辑模式(press <kbd>Enter</kbd> to enable)<div class="container-fluid"><div class="col-md-6"><div class="quickhelp"><span class="shortcut_key"><kbd>Tab</kbd></span><span class="shortcut_descr"> : 代码补全或缩进</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Tab</kbd></span><span class="shortcut_descr"> : 工具提示</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-]</kbd></span><span class="shortcut_descr"> : 缩进</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-[</kbd></span><span class="shortcut_descr"> : 取消缩进</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-A</kbd></span><span class="shortcut_descr"> : 选择所有</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Z</kbd></span><span class="shortcut_descr"> : 撤销</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-/</kbd></span><span class="shortcut_descr"> : 注释</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-D</kbd></span><span class="shortcut_descr"> : 删除整行</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-U</kbd></span><span class="shortcut_descr"> : 撤销</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Insert</kbd></span><span class="shortcut_descr"> : 折叠重写标志</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Home</kbd></span><span class="shortcut_descr"> : 跳转至最上方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Up</kbd></span><span class="shortcut_descr"> : 跳转至最上方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-End</kbd></span><span class="shortcut_descr"> : 跳转至最下方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Down</kbd></span><span class="shortcut_descr"> : 跳转至最下方单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Left</kbd></span><span class="shortcut_descr"> : 左移一个字</span></div></div><div class="col-md-6"><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Right</kbd></span><span class="shortcut_descr"> : 右移一个字</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Backspace</kbd></span><span class="shortcut_descr"> : 删除前方文字</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Delete</kbd></span><span class="shortcut_descr"> : 删除后方文字</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Y</kbd></span><span class="shortcut_descr"> : 重做</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Alt-U</kbd></span><span class="shortcut_descr"> : 重做</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-M</kbd></span><span class="shortcut_descr"> : 进入命令模式</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Shift-F</kbd></span><span class="shortcut_descr"> : 打开命令面板</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Shift-P</kbd></span><span class="shortcut_descr"> : 打开命令面板</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Esc</kbd></span><span class="shortcut_descr"> : 进入命令模式</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Shift-Enter</kbd></span><span class="shortcut_descr"> : 运行单元格，选择下方</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Enter</kbd></span><span class="shortcut_descr"> : 运行单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Alt-Enter</kbd></span><span class="shortcut_descr"> : 运行单元格并下方插入</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-Shift-Minus</kbd></span><span class="shortcut_descr"> : 拆分鼠标所在单元格</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Ctrl-S</kbd></span><span class="shortcut_descr"> : 保存并设置检查点</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Down</kbd></span><span class="shortcut_descr"> : 下移鼠标</span></div><div class="quickhelp"><span class="shortcut_key"><kbd>Up</kbd></span><span class="shortcut_descr"> : 上移鼠标</span></div></div></div></div>

# %% [markdown]
# ## 课程设置

# %% [markdown]
# |<font size=6>模块名称    | <font size=6>主要内容                                        |
# | -------------------- | ----------------------------------------------- |
# |<font size=5> <mark>`数据结构是一切的基石`</mark> |<font size=5> Numpy、Pandas、xarray、netCDF4                  |
# |<font size=5> <mark>`科学分析的Python实现`</mark> |<font size=5> scipy、Scikit-learn、statsmodel、MK、eofs……     |
# |<font size=5> <mark>`可视化是最主要的出口`</mark> |<font size=5> 可视化的核心matplotlib + 气象是门地球学科cartopy  |
# |<font size=5> <mark>`专业的事情专业干`</mark>     |<font size=5> Metpy、pycwr、cinrad、satpy…                    |
# ---

# %% [markdown]
# <img src='pics/库包版本信息.png' align='center'>

# %% [markdown]
# ![image.png](attachment:f83cb727-137d-421d-90aa-95f191601702.png)

# %% [markdown]
# <img src='pics/Matplotlib/flow.png' align='center'>
